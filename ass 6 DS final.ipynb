# %%
#importing libraries

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
df1 = pd.read_csv(r'C:\Users\666\Desktop\day_1.csv')
df1.head()
# Out:
#    batch  glucose conc [g/l]  biomass conc [g/l]  DO [mg/l]  \
# 0      1                 100                 1.0       10.0
# 1      2                 150                 2.0       10.0
# 2      3                 120                 2.0       15.0
# 3      4                 150                 2.5       15.0
# 4      5                 150                 3.0       15.0
#
#    gluconic acid conc [g/l]
# 0                     6.416
# 1                    48.015
# 2                    27.100
# 3                    57.946
# 4                    57.389

# %%
df2 = pd.read_csv(r'C:\Users\666\Desktop\day_2.csv')
df2.head()
# Out:
#    batch  glucose conc [g/l]  biomass conc [g/l]  DO [g/l]  \
# 0     26               100.0                 2.0     0.015
# 1     27               150.0                 2.0     0.015
# 2     28               120.0                 2.0     0.020
# 3     29               150.0                 2.0       NaN
# 4     30               150.0                 2.5     0.020
#
#    gluconic acid conc [g/l]
# 0                     7.829
# 1                    57.261
# 2                    31.486
# 3                    66.900
# 4                    67.449

# %%
df = pd.concat([df1, df2], axis=0)
df.set_index("batch")
df.head()
# Out:
#    batch  glucose conc [g/l]  biomass conc [g/l]  DO [mg/l]  \
# 0      1               100.0                 1.0       10.0
# 1      2               150.0                 2.0       10.0
# 2      3               120.0                 2.0       15.0
# 3      4               150.0                 2.5       15.0
# 4      5               150.0                 3.0       15.0
#
#    gluconic acid conc [g/l]  DO [g/l]
# 0                     6.416       NaN
# 1                    48.015       NaN
# 2                    27.100       NaN
# 3                    57.946       NaN
# 4                    57.389       NaN

# %%
#getting info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47 entries, 0 to 20
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   batch                     47 non-null     int64
#  1   glucose conc [g/l]        45 non-null     float64
#  2   biomass conc [g/l]        45 non-null     float64
#  3   DO [mg/l]                 25 non-null     float64
#  4   gluconic acid conc [g/l]  47 non-null     float64
#  5   DO [g/l]                  20 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 2.6 KB

# %%
neg = df < 0
neg.sum()
# Out:
# batch                       0
# glucose conc [g/l]          0
# biomass conc [g/l]          1
# DO [mg/l]                   0
# gluconic acid conc [g/l]    0
# DO [g/l]                    0
# dtype: int64

# %%
b=df['biomass conc [g/l]']
for i in range (len(b)):
    if b[i] < 0:
        print(i,T[i])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9704\289085638.py in ?()
#       1 b=df['biomass conc [g/l]']
#       2 for i in range (len(b)):
# ----> 3     if b[i] < 0:
#       4         print(i,T[i])
#
# c:\Users\666\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df.drop(labels=45,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\666\Desktop\ass 6 DS1.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/666/Desktop/ass%206%20DS1.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> df.drop(labels=45,inplace=True)
#
# NameError: name 'df' is not defined

# %%
df.isna().sum()
# Out:
# batch                        0
# glucose conc [g/l]           2
# biomass conc [g/l]           2
# DO [mg/l]                   22
# gluconic acid conc [g/l]     0
# DO [g/l]                    27
# dtype: int64

# %%
df.dropna(subset=['biomass conc [g/l]'], inplace=True)
df
# Out:
#     batch  glucose conc [g/l]  biomass conc [g/l]  DO [mg/l]  \
# 0       1               100.0                 1.0       10.0
# 1       2               150.0                 2.0       10.0
# 2       3               120.0                 2.0       15.0
# 3       4               150.0                 2.5       15.0
# 4       5               150.0                 3.0       15.0
# 5       6               120.0                 2.0       25.0
# 6       7               120.0                 2.0       30.0
# 7       8               150.0                 2.0       30.0
# 8       9               150.0                 3.0       25.0
# 9      10               150.0                 2.0       40.0
# 10     10               150.0                 2.0       40.0
# 12     12               150.0                 2.0       50.0
# 13     13               180.0                 2.0       50.0
# 14     14               150.0                 3.0       40.0
# ...

# %%
df.dropna(subset=['glucose conc [g/l]'], inplace=True)
df
# Out:
#     batch  glucose conc [g/l]  biomass conc [g/l]  DO [mg/l]  \
# 0       1               100.0                 1.0       10.0
# 1       2               150.0                 2.0       10.0
# 2       3               120.0                 2.0       15.0
# 3       4               150.0                 2.5       15.0
# 4       5               150.0                 3.0       15.0
# 5       6               120.0                 2.0       25.0
# 6       7               120.0                 2.0       30.0
# 7       8               150.0                 2.0       30.0
# 8       9               150.0                 3.0       25.0
# 9      10               150.0                 2.0       40.0
# 10     10               150.0                 2.0       40.0
# 12     12               150.0                 2.0       50.0
# 13     13               180.0                 2.0       50.0
# 14     14               150.0                 3.0       40.0
# ...

# %%
mode_type1 = df['DO [g/l]'].mode()[0]
df['DO [g/l]'].fillna(mode_type1, inplace=True)
df
# Out:
#     batch  glucose conc [g/l]  biomass conc [g/l]  DO [mg/l]  \
# 0       1               100.0                 1.0       10.0
# 1       2               150.0                 2.0       10.0
# 2       3               120.0                 2.0       15.0
# 3       4               150.0                 2.5       15.0
# 4       5               150.0                 3.0       15.0
# 5       6               120.0                 2.0       25.0
# 6       7               120.0                 2.0       30.0
# 7       8               150.0                 2.0       30.0
# 8       9               150.0                 3.0       25.0
# 9      10               150.0                 2.0       40.0
# 10     10               150.0                 2.0       40.0
# 12     12               150.0                 2.0       50.0
# 13     13               180.0                 2.0       50.0
# 14     14               150.0                 3.0       40.0
# ...

# %%
mode_type2 = df['DO [mg/l]'].mode()[0]
df['DO [mg/l]'].fillna(mode_type2, inplace=True)
df
# Out:
#     batch  glucose conc [g/l]  biomass conc [g/l]  DO [mg/l]  \
# 0       1               100.0                 1.0       10.0
# 1       2               150.0                 2.0       10.0
# 2       3               120.0                 2.0       15.0
# 3       4               150.0                 2.5       15.0
# 4       5               150.0                 3.0       15.0
# 5       6               120.0                 2.0       25.0
# 6       7               120.0                 2.0       30.0
# 7       8               150.0                 2.0       30.0
# 8       9               150.0                 3.0       25.0
# 9      10               150.0                 2.0       40.0
# 10     10               150.0                 2.0       40.0
# 12     12               150.0                 2.0       50.0
# 13     13               180.0                 2.0       50.0
# 14     14               150.0                 3.0       40.0
# ...

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

df
# Out:
#     batch  glucose conc [g/l]  biomass conc [g/l]  DO [mg/l]  \
# 0       1               100.0                 1.0       10.0
# 1       2               150.0                 2.0       10.0
# 2       3               120.0                 2.0       15.0
# 3       4               150.0                 2.5       15.0
# 4       5               150.0                 3.0       15.0
# 5       6               120.0                 2.0       25.0
# 6       7               120.0                 2.0       30.0
# 7       8               150.0                 2.0       30.0
# 8       9               150.0                 3.0       25.0
# 9      10               150.0                 2.0       40.0
# 11     11               150.0                 NaN       45.0
# 12     12               150.0                 2.0       50.0
# 13     13               180.0                 2.0       50.0
# 14     14               150.0                 3.0       40.0
# ...

# %%
df.dtypes
# Out:
# batch                         int64
# glucose conc [g/l]          float64
# biomass conc [g/l]          float64
# DO [mg/l]                   float64
# gluconic acid conc [g/l]    float64
# DO [g/l]                    float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# batch                        0
# glucose conc [g/l]           2
# biomass conc [g/l]           2
# DO [mg/l]                   22
# gluconic acid conc [g/l]     0
# DO [g/l]                    27
# dtype: int64

# %% [markdown]
# visualiation

# %%
df_bio= df.groupby('biomass conc [g/l]')['biomass conc [g/l]'].count()
df_bio

df_bio.plot(kind='pie', figsize=(20, 7), labels=None,autopct='%1.1f%%',startangle=90)

plt.title('biomass conc [g/l]')

plt.ylabel('')

plt.legend(labels=df_bio.index, loc='lower right')

# %%
df['DO [g/l]'].plot(kind='box')

plt.title('Box plotting DO [g/l]')

plt.ylabel('y_lable')

plt.yticks(range(0,1,3))

plt.grid()

# %%
df['glucose conc [g/l]'].plot(kind='hist')

plt.title('gluconic conc [g/l]')

plt.xlabel('gluconic conc [g/l]')

plt.xticks(rotation=0)

plt.ylabel('y_label')

plt.grid()

# %%
df['gluconic acid conc [g/l]'].plot(kind='hist', bins=10)

plt.title('gluconic acid conc [g/l]')

plt.xlabel('gluconic acid conc [g/l]')

plt.xticks(rotation=90)

plt.ylabel('y_label')

plt.grid()

# %%
df['DO [mg/l]'].plot(kind='box')

plt.title(' DO [mg/l]')

plt.ylabel('y_lable')

plt.yticks(range(0,1,6))

plt.grid()

# %%
df_batch1 = df.groupby('batch', as_index=False)['glucose conc [g/l]'].count()
df_batch1
# Out:
#     batch  glucose conc [g/l]
# 0       1                   1
# 1       2                   1
# 2       3                   1
# 3       4                   1
# 4       5                   1
# 5       6                   1
# 6       7                   1
# 7       8                   1
# 8       9                   1
# 9      10                   2
# 10     11                   1
# 11     12                   1
# 12     13                   1
# 13     14                   1
# 14     15                   1
# 15     16                   1
# 16     17                   1
# 17     18                   1
# 18     19                   1
# 19     20                   1
# 20     21                   1
# 21     22                   1
# 22     23                   1
# 23     24                   1
# 24     25                   1
# 25     26                   1
# 26     27                   1
# 27     28                   1
# 28     29                   1
# 29     30                   1
# ...

# %%
df_batch1.plot(kind='bar')


plt.title('visual 1')

plt.xlabel('batch')

plt.ylabel('glucose conc [g/l]')

plt.xticks(rotation=0)

plt.grid()

# %%
df_DO = df.groupby('DO [mg/l]', as_index=False)['DO [g/l]'].sum()
df_DO
# Out:
#    DO [mg/l]  DO [g/l]
# 0       10.0       0.0
# 1       15.0       0.0
# 2       25.0       0.0
# 3       30.0       0.0
# 4       40.0       0.0
# 5       45.0       0.0
# 6       50.0       0.0
# 7       55.0       0.0
# 8       60.0       0.0

# %%
df_DO.plot(kind='line', figsize=(15, 5), x='DO [mg/l]', y='DO [g/l]')

plt.title('DO [mg/l] vs DO [g/l]', y=1.1)

plt.xlabel('DO [mg/l]')

plt.ylabel('DO [g/l]')

plt.xticks(rotation=45)

plt.margins(x=0)

plt.grid()

# %%
df_glucose_bio= df.groupby('glucose conc [g/l]', as_index=False)['biomass conc [g/l]'].sum()
df_glucose_bio
# Out:
#    glucose conc [g/l]  biomass conc [g/l]
# 0               100.0                 8.0
# 1               120.0                12.5
# 2               150.0                60.0
# 3               160.0                 5.5
# 4               162.0                 3.0
# 5               165.0                -3.0
# 6               166.0                 3.0
# 7               175.0                 3.0
# 8               180.0                 7.0

# %%
df_glucose_bio.plot(kind='line', figsize=(15, 5), x='glucose conc [g/l]', y='biomass conc [g/l]')

plt.title('gluconic acid conc [g/l] vs biomass conc [g/l]', y=1.1)

plt.xlabel('glucose conc [g/l]')

plt.ylabel('biomass conc [g/l]')

plt.xticks(rotation=47)

plt.margins(x=0)

plt.grid()

# %%
df_gluss = df.groupby('glucose conc [g/l]', as_index=False)['gluconic acid conc [g/l]'].sum()
df_gluss
# Out:
#    glucose conc [g/l]  gluconic acid conc [g/l]
# 0               100.0                    42.718
# 1               120.0                   236.322
# 2               150.0                  2841.804
# 3               160.0                   325.487
# 4               162.0                   164.870
# 5               165.0                   167.910
# 6               166.0                   169.450
# 7               175.0                  1760.490
# 8               180.0                   701.670

# %%
df_gluss.plot(kind='bar')

plt.title('glucose conc [g/l] vs gluconic acid conc [g/l]')

plt.xlabel('glucose conc [g/l]')

plt.ylabel('gluconic acid conc [g/l]')

plt.xticks(rotation=0)

plt.grid()
