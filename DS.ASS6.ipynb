# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Untitled-1.ipynb Cell 1 line 6
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=3'>4</a> import seaborn as sns
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=4'>5</a> from scipy import stats
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=5'>6</a> from sklearn.linear_model import LinearRegression
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=6'>7</a> from sklearn.preprocessing import PolynomialFeatures
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=7'>8</a> from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# reading data
df = pd.read_csv('data science data.csv')
df.head()
# Out:
#    T(oC)  wt.% salt  vapour pressure
# 0      0        0.0            4.579
# 1     10        0.0            9.210
# 2     20        0.0           17.540
# 3     30        0.0           31.830
# 4     40        0.0           55.340

# %% [markdown]
# # Get information about the columns of the DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   T(oC)            108 non-null    int64
#  1   wt.% salt        108 non-null    float64
#  2   vapour pressure  108 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 2.7 KB

# %%
df.describe()
# Out:
#             T(oC)   wt.% salt  vapour pressure
# count  108.000000  108.000000       108.000000
# mean    55.000000   10.833333       253.764435
# std     34.681461    7.764044       306.988988
# min      0.000000    0.000000         3.500000
# 25%     27.500000    5.000000        22.910000
# 50%     55.000000   10.000000       104.670000
# 75%     82.500000   15.000000       370.102500
# max    110.000000   25.000000      1074.500000

# %% [markdown]
# # Simple Linear Regression

# %%
lr = LinearRegression()


x = df[['T(oC)']]
y = df['vapour pressure']


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
print('Training set: ', x_train.shape, y_train.shape)
print('Testing set: ', x_test.shape, y_test.shape)


lr.fit(x_train, y_train)
print('Coefficients: ', lr.coef_)
print('Intercept: ', lr.intercept_)


y_pred = lr.predict(x_test)
print('Predictions: ', y_pred.shape)




print('Mean squared error: {:.2f}'.format(mean_squared_error(y_test, y_pred)))
print('Coefficient of determination (R-squared): {:.2f}'.format(r2_score(y_test, y_pred)))


x_fit = np.arange(0.0, 10.0, 0.1)
y_fit = lr.intercept_ + lr.coef_[0] * x_fit
plt.figure(figsize=(10, 6))
plt.scatter(x_test, y_test, color='blue')
plt.plot(x_fit, y_fit, color='red')
plt.title('Linear Regression')
plt.xlabel('T(oC)')
plt.ylabel('vapour pressure')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Untitled-1.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W4sdW50aXRsZWQ%3D?line=0'>1</a> lr = LinearRegression()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W4sdW50aXRsZWQ%3D?line=3'>4</a> x = df[['T(oC)']]
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W4sdW50aXRsZWQ%3D?line=4'>5</a> y = df['vapour pressure']
#
# NameError: name 'LinearRegression' is not defined

# %%
lr = LinearRegression()


x = df[['wt.% salt']]
y = df['vapour pressure']


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
print('Training set: ', x_train.shape, y_train.shape)
print('Testing set: ', x_test.shape, y_test.shape)


lr.fit(x_train, y_train)
print('Coefficients: ', lr.coef_)
print('Intercept: ', lr.intercept_)


y_pred = lr.predict(x_test)
print('Predictions: ', y_pred.shape)




print('Mean squared error: {:.2f}'.format(mean_squared_error(y_test, y_pred)))
print('Coefficient of determination (R-squared): {:.2f}'.format(r2_score(y_test, y_pred)))


x_fit = np.arange(0.0, 10.0, 0.1)
y_fit = lr.intercept_ + lr.coef_[0] * x_fit
plt.figure(figsize=(10, 6))
plt.scatter(x_test, y_test, color='blue')
plt.plot(x_fit, y_fit, color='red')
plt.title('Linear Regression')
plt.xlabel('wt.% salt')
plt.ylabel('vapour pressure')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Untitled-1.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W6sdW50aXRsZWQ%3D?line=0'>1</a> lr = LinearRegression()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W6sdW50aXRsZWQ%3D?line=3'>4</a> x = df[['wt.% salt']]
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W6sdW50aXRsZWQ%3D?line=4'>5</a> y = df['vapour pressure']
#
# NameError: name 'LinearRegression' is not defined

# %% [markdown]
# # Multiple Linear Regression

# %%
lr = LinearRegression()


x = df[['wt.% salt', 'T(oC)']]
y = df['vapour pressure']


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
print('Training set: ', x_train.shape, y_train.shape)
print('Testing set: ', x_test.shape, y_test.shape)


lr.fit(x_train, y_train)
print('Coefficients: ', lr.coef_)
print('Intercept: ', lr.intercept_)


y_pred = lr.predict(x_test)
print('Predictions: ', y_pred.shape)


print('Mean squared error: {:.2f}'.format(mean_squared_error(y_test, y_pred)))
print('Coefficient of determination (R-squared): {:.2f}'.format(r2_score(y_test, y_pred)))


x_fit = np.arange(0.0, 10.0, 0.1)
y_fit = np.arange(0.0, 30.0, 0.1)
X, Y = np.meshgrid(x_fit, y_fit)
Z = lr.intercept_ + lr.coef_[0] * X + lr.coef_[1] * Y
fig = plt.figure(figsize=(20, 20))


n_rows = 3
n_cols = 3
angles = np.linspace(0, 360, n_rows * n_cols + 1)[:-1]
for i, angle in enumerate(angles):
    ax = fig.add_subplot(n_rows, n_cols, i + 1, projection='3d')
    ax.scatter(x_test['wt.% salt'], x_test['T(oC)'], y_test, color='blue')
    ax.plot_surface(X, Y, Z, color='red', alpha=0.3)
    ax.set_xlabel('wt.% salt')
    ax.set_ylabel('T(oC)')
    ax.set_zlabel('vapour pressure')
    ax.view_init(20, angle)

plt.show()

# %% [markdown]
# # Non-Linear Regression

# %%
lr = LinearRegression()


x = df[['T(oC)']]
y = df['vapour pressure']


poly = PolynomialFeatures(degree=2, include_bias=False)
x_poly = poly.fit_transform(x)
print('Polynomial features: ', x_poly.shape)


x_train, x_test, y_train, y_test = train_test_split(x_poly, y, test_size=0.2)
print('Training set: ', x_train.shape, y_train.shape)
print('Testing set: ', x_test.shape, y_test.shape)



lr.fit(x_train, y_train)
print('Coefficients: ', lr.coef_)
print('Intercept: ', lr.intercept_)



y_pred = lr.predict(x_test)
print('Predictions: ', y_pred.shape)


print('Mean squared error: {:.2f}'.format(mean_squared_error(y_test, y_pred)))
print('Coefficient of determination (R-squared): {:.2f}'.format(r2_score(y_test, y_pred)))


plt.figure(figsize=(10, 6))
plt.scatter(x_test[:, 0], y_test, color='blue')
x_fit = np.arange(0.0, 10.0, 0.1)
y_fit = lr.intercept_ + lr.coef_[0] * x_fit + lr.coef_[1] * x_fit ** 2
plt.plot(x_fit, y_fit, color='red')
plt.title('Polynomial Regression')
plt.xlabel('T(oC)')
plt.ylabel('vapour pressure')
plt.show()

# %%
lr = LinearRegression()


x = df[['wt.% salt']]
y = df['vapour pressure']


poly = PolynomialFeatures(degree=2, include_bias=False)
x_poly = poly.fit_transform(x)
print('Polynomial features: ', x_poly.shape)


x_train, x_test, y_train, y_test = train_test_split(x_poly, y, test_size=0.2)
print('Training set: ', x_train.shape, y_train.shape)
print('Testing set: ', x_test.shape, y_test.shape)



lr.fit(x_train, y_train)
print('Coefficients: ', lr.coef_)
print('Intercept: ', lr.intercept_)



y_pred = lr.predict(x_test)
print('Predictions: ', y_pred.shape)


print('Mean squared error: {:.2f}'.format(mean_squared_error(y_test, y_pred)))
print('Coefficient of determination (R-squared): {:.2f}'.format(r2_score(y_test, y_pred)))


plt.figure(figsize=(10, 6))
plt.scatter(x_test[:, 0], y_test, color='blue')
x_fit = np.arange(0.0, 10.0, 0.1)
y_fit = lr.intercept_ + lr.coef_[0] * x_fit + lr.coef_[1] * x_fit ** 2
plt.plot(x_fit, y_fit, color='red')
plt.title('Polynomial Regression')
plt.xlabel('wt.% salt')
plt.ylabel('vapour pressure')
plt.show()
